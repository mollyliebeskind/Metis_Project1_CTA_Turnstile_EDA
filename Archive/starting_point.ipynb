# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import datetime

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %% [markdown]
# # Download and load MTA turnstile data

# %%
def all_saturdays(start_date, end_date):
    modified_end_date = datetime.datetime.strptime(end_date,'%m/%d/%Y')+ datetime.timedelta(weeks = 1)
    saturday_list = pd.date_range(start =start_date, end =modified_end_date,
                              freq='W-SAT').strftime('%m/%d/%Y').tolist()
    return saturday_list

# %%
def import_mta(date):
    formatted_date = date[-2:]+date[:2]+date[3:5]
    base_url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    date_url = base_url.format(formatted_date)
    date_data = pd.read_csv(date_url)
    return date_data

# %%
def mta_to_df(saturday_list):
    dict_of_dfs = {}
    for saturday in saturday_list:
        dict_of_dfs[saturday] = pd.DataFrame(import_mta(saturday))
    mta =pd.DataFrame()
    for val in dict_of_dfs.values():
        mta = pd.concat([mta, val])
    return mta

# %%
# start_date = input("Enter start date (X/X/XXXX): ")
# end_date = input("Enter end date (X/X/XXXX): ")
start_date = '3/1/2019'
end_date = '6/1/2019'

# %%
saturday_list = all_saturdays(start_date,end_date)

# %%
# print(saturday_list)

# %%
mta = mta_to_df(saturday_list)

# %%
mta.tail()

# %% [markdown]
# # In case of later breakage

# %%
mta.to_csv(r'mta.csv')

# %%
# mta = pd.read_csv('mta.csv')

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## column names

# %%
mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3062159 entries, 0 to 3062158
# Data columns (total 12 columns):
# Unnamed: 0                                                              int64
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                 int64
# EXITS                                                                   int64
# dtypes: int64(3), object(9)
# memory usage: 280.3+ MB

# %%
mta.columns
# Out:
# Index(['Unnamed: 0', 'C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION',
#        'DATE', 'TIME', 'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
mta.columns = mta.columns.str.strip().str.lower().str.replace('/',"_")

# %%
mta.columns
# Out:
# Index(['unnamed: 0', 'c_a', 'unit', 'scp', 'station', 'linename', 'division',
#        'date', 'time', 'desc', 'entries', 'exits'],
#       dtype='object')

# %% [markdown]
# ## create datetime column from date and time

# %%
mta["datetime"] = pd.to_datetime(mta.date + " " + mta.time, format="%m/%d/%Y %H:%M:%S")

# %%
mta.head()
# Out:
#    unnamed: 0   c_a  unit       scp station linename division        date  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/23/2019
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/23/2019
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/23/2019
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/23/2019
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT  02/23/2019
#
#        time     desc  entries    exits            datetime
# 0  03:00:00  REGULAR  6955483  2359112 2019-02-23 03:00:00
# 1  07:00:00  REGULAR  6955494  2359125 2019-02-23 07:00:00
# 2  11:00:00  REGULAR  6955554  2359199 2019-02-23 11:00:00
# 3  15:00:00  REGULAR  6955714  2359248 2019-02-23 15:00:00
# 4  19:00:00  REGULAR  6956004  2359292 2019-02-23 19:00:00

# %% [markdown]
# ## filter to previously specified dates

# %%
mta.date.value_counts().sort_index()
# Out:
# 02/23/2019    28827
# 02/24/2019    29109
# 02/25/2019    28842
# 02/26/2019    29777
# 02/27/2019    28903
#               ...
# 06/03/2019    30022
# 06/04/2019    29513
# 06/05/2019    29484
# 06/06/2019    29213
# 06/07/2019    28745
# Name: date, Length: 105, dtype: int64

# %%
mta.date = pd.to_datetime(mta.date,format="%m/%d/%Y")

# %%
mta = mta[(mta.date >= start_date)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-665ed02c7657> in <module>
# ----> 1 mta = mta[(mta.date >= start_date)]
#
# NameError: name 'start_date' is not defined

# %%
mta = mta[(mta.date <= end_date)]

# %%
mta.date.value_counts().sort_index()
# Out:
# 2019-02-23    28827
# 2019-02-24    29109
# 2019-02-25    28842
# 2019-02-26    29777
# 2019-02-27    28903
#               ...
# 2019-06-03    30022
# 2019-06-04    29513
# 2019-06-05    29484
# 2019-06-06    29213
# 2019-06-07    28745
# Name: date, Length: 105, dtype: int64

# %%
mta.drop(columns = ['time'], inplace = True)

# %%
mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3062159 entries, 0 to 3062158
# Data columns (total 12 columns):
# unnamed: 0    int64
# c_a           object
# unit          object
# scp           object
# station       object
# linename      object
# division      object
# date          datetime64[ns]
# desc          object
# entries       int64
# exits         int64
# datetime      datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(7)
# memory usage: 280.3+ MB

# %%
mta.head(10)
# Out:
#    unnamed: 0   c_a  unit       scp station linename division       date  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23
# 5           5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23
# 6           6  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24
# 7           7  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24
# 8           8  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24
# 9           9  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24
#
#       desc  entries    exits            datetime
# 0  REGULAR  6955483  2359112 2019-02-23 03:00:00
# 1  REGULAR  6955494  2359125 2019-02-23 07:00:00
# 2  REGULAR  6955554  2359199 2019-02-23 11:00:00
# 3  REGULAR  6955714  2359248 2019-02-23 15:00:00
# 4  REGULAR  6956004  2359292 2019-02-23 19:00:00
# 5  REGULAR  6956147  2359325 2019-02-23 23:00:00
# 6  REGULAR  6956177  2359332 2019-02-24 03:00:00
# 7  REGULAR  6956184  2359339 2019-02-24 07:00:00
# 8  REGULAR  6956215  2359388 2019-02-24 11:00:00
# 9  REGULAR  6956315  2359432 2019-02-24 15:00:00

# %% [markdown]
# ## duplicates

# %%
(mta
 .groupby(["c_a", "unit", "scp", "station", "datetime"])
 .entries.count()
 .reset_index()
 .sort_values("entries", ascending=False)).head(50)
# Out:
#            c_a  unit       scp          station            datetime  entries
# 442825    G009  R151  02-00-03  CONEY IS-STILLW 2019-05-16 17:00:00        2
# 1496797   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-25 05:00:00        2
# 1496794   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-24 17:00:00        2
# 807316    N071  R013  00-00-03   34 ST-PENN STA 2019-02-28 07:00:00        2
# 806038    N071  R013  00-00-01   34 ST-PENN STA 2019-02-28 07:00:00        2
# 807314    N071  R013  00-00-03   34 ST-PENN STA 2019-02-28 03:00:00        2
# 807312    N071  R013  00-00-03   34 ST-PENN STA 2019-02-27 19:00:00        2
# 1496795   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-24 21:00:00        2
# 1496796   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-25 01:00:00        2
# 2502831   R283  R221  00-00-02           167 ST 2019-04-16 04:00:00        2
# 1010893   N135  R385  01-03-01    ROCKAWAY BLVD 2019-03-31 13:00:00        2
# 1496798   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-25 09:00:00        2
# 1496799   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-25 13:00:00        2
# 2502828   R283  R221  00-00-02           167 ST 2019-04-15 16:00:00        2
# 2502827   R283  R221  00-00-02           167 ST 2019-04-15 12:00:00        2
# 1496800   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-25 17:00:00        2
# 1496801   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-25 21:00:00        2
# 605490   JFK03  R536  00-00-03  JFK JAMAICA CT1 2019-04-07 01:00:00        2
# 806036    N071  R013  00-00-01   34 ST-PENN STA 2019-02-28 03:00:00        2
# 806035    N071  R013  00-00-01   34 ST-PENN STA 2019-02-27 23:00:00        2
# 720336    N045  R187  01-00-00     81 ST-MUSEUM 2019-06-01 17:00:00        2
# 1496785   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-23 05:00:00        2
# 2501540   R283  R221  00-00-00           167 ST 2019-04-15 16:00:00        2
# 2501543   R283  R221  00-00-00           167 ST 2019-04-16 04:00:00        2
# 720341    N045  R187  01-00-00     81 ST-MUSEUM 2019-06-02 17:00:00        2
# 608840   JFK03  R536  00-03-02  JFK JAMAICA CT1 2019-04-07 01:00:00        2
# 604797   JFK03  R536  00-00-02  JFK JAMAICA CT1 2019-04-07 01:00:00        2
# 2196256   R188  R037  00-06-01           207 ST 2019-02-28 07:00:00        2
# 1496784   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-23 01:00:00        2
# 1496786   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-23 09:00:00        2
# 806034    N071  R013  00-00-01   34 ST-PENN STA 2019-02-27 19:00:00        2
# 1496787   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-23 13:00:00        2
# 1496788   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-23 17:00:00        2
# 1496789   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-23 21:00:00        2
# 1496790   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-24 01:00:00        2
# 1496791   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-24 05:00:00        2
# 1496792   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-24 09:00:00        2
# 1496793   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-24 13:00:00        2
# 1496803   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-26 05:00:00        2
# 1496804   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-26 09:00:00        2
# 1496805   N519  R461  00-03-01  B'WAY-LAFAYETTE 2019-03-26 13:00:00        2
# 805395    N071  R013  00-00-00   34 ST-PENN STA 2019-02-27 19:00:00        2
# 2503476   R283  R221  00-00-03           167 ST 2019-04-16 04:00:00        2
# 721586    N045  R187  01-00-02     81 ST-MUSEUM 2019-06-02 17:00:00        2
# 2195020   R188  R037  00-00-02           207 ST 2019-02-28 07:00:00        2
# 720964    N045  R187  01-00-01     81 ST-MUSEUM 2019-06-02 17:00:00        2
# 720959    N045  R187  01-00-01     81 ST-MUSEUM 2019-06-01 17:00:00        2
# 1520788   N525  R142  01-00-04   DELANCEY/ESSEX 2019-05-11 05:00:00        2
# 1984944   R123  R290  00-00-02       HOUSTON ST 2019-02-28 04:00:00        2
# 805396    N071  R013  00-00-00   34 ST-PENN STA 2019-02-27 23:00:00        2

# %%
# mask = ((mta["c_a"] == "G009") & 
#     (mta["unit"] == "R151") & 
#     (mta["scp"] == "02-00-04") & 
#     (mta["station"] == "CONEY IS-STILLW") &
#     (mta["datetime"] == "2019-05-16 17:00:00"))
# mta[mask].head(10)

# %%
mta.sort_values(["c_a", "unit", "scp", "station", "datetime"], inplace=True, ascending=False)
mta.drop_duplicates(subset=["c_a", "unit", "scp", "station", "datetime"], inplace=True)

# %%
(mta
 .groupby(["c_a", "unit", "scp", "station", "datetime"])
 .entries.count()
 .reset_index()
 .sort_values("entries", ascending=False)).head(10)
# Out:
#           c_a  unit       scp         station            datetime  entries
# 0        A002  R051  02-00-00           59 ST 2019-02-23 03:00:00        1
# 2041373  R141  R031  00-03-04  34 ST-PENN STA 2019-04-19 00:00:00        1
# 2041364  R141  R031  00-03-04  34 ST-PENN STA 2019-04-17 12:00:00        1
# 2041365  R141  R031  00-03-04  34 ST-PENN STA 2019-04-17 16:00:00        1
# 2041366  R141  R031  00-03-04  34 ST-PENN STA 2019-04-17 20:00:00        1
# 2041367  R141  R031  00-03-04  34 ST-PENN STA 2019-04-18 00:00:00        1
# 2041368  R141  R031  00-03-04  34 ST-PENN STA 2019-04-18 04:00:00        1
# 2041369  R141  R031  00-03-04  34 ST-PENN STA 2019-04-18 08:00:00        1
# 2041370  R141  R031  00-03-04  34 ST-PENN STA 2019-04-18 12:00:00        1
# 2041371  R141  R031  00-03-04  34 ST-PENN STA 2019-04-18 16:00:00        1

# %%
mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3062056 entries, 3062158 to 0
# Data columns (total 12 columns):
# unnamed: 0    int64
# c_a           object
# unit          object
# scp           object
# station       object
# linename      object
# division      object
# date          datetime64[ns]
# desc          object
# entries       int64
# exits         int64
# datetime      datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(7)
# memory usage: 303.7+ MB

# %%
mta.to_csv(r'mta_cleaned.csv')

# %%
# mta = pd.read_csv('mta.csv')

# %% [markdown]
# ## daily entries by turnstile

# %%
mta.head(10)

# %%
by_turnstile_date = mta.groupby(['c_a', 'unit', 'scp', 'station', mta.datetime.dt.date])

# %%
mta_daily = by_turnstile_date['entries'].min().reset_index()

# %%
mta_daily['daily_entries'] = mta_daily.groupby(['c_a', 'unit', 'scp', 'station'])['entries'].diff().shift(-1)

# %%
mta_daily.describe([.95,.997])

# %%
mta_daily = mta_daily.reset_index()
check_distribution = mta_daily[mta_daily.daily_entries.notnull()]

plt.figure(figsize=(10,4))
sns.distplot(check_distribution.daily_entries)

# %%
#dropping rows with negative daily entries
mta_daily = mta_daily[mta_daily.daily_entries >= 0]

# %%
#dropping rows with the top .3% of daily entries
mta_daily = mta_daily[mta_daily.daily_entries < mta_daily.daily_entries.quantile(q =.997)]

# %%
mta_daily.describe()

# %%
check_distribution = mta_daily[mta_daily.daily_entries.notnull()]

plt.figure(figsize=(10,4))
sns.distplot(check_distribution.daily_entries)

# %%
mta_daily.to_csv(r'mta_daily.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6142d04a1169> in <module>
# ----> 1 mta_daily.to_csv(r'mta_daily.csv')
#
# NameError: name 'mta_daily' is not defined

# %%
# mta_daily = pd.read_csv('mta_daily.csv')

# %% [markdown]
# ### challenge 4

# %%
turnstile = mta_daily[
    (mta_daily["c_a"] == "G009") & 
    (mta_daily["unit"] == "R151") & 
    (mta_daily["scp"] == "02-00-04") & 
    (mta_daily["station"] == "CONEY IS-STILLW")
    ].groupby(["datetime"]).daily_entries.max()

plt.figure(figsize=(10,4))
plt.plot(turnstile);

# %% [markdown]
# ### challenge 5

# %%
by_ca_unit_station_date = (mta_daily.groupby(['c_a', 'unit', 'station', 'datetime'])
                           .daily_entries.agg({'daily_entries': 'sum'}))
by_ca_unit_station_date.head()

# %% [markdown]
# ### challenge 6

# %%
by_station = (mta_daily.groupby(['station', 'datetime'])
                           .daily_entries.agg({'daily_entries': 'sum'}))
by_station.tail()
# Out:
# /opt/miniconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#                       daily_entries
# station   datetime
# ZEREGA AV 2019-05-27         1111.0
#           2019-05-28         2746.0
#           2019-05-29         2815.0
#           2019-05-30         2841.0
#           2019-05-31         2740.0

# %% [markdown]
# ### challenge 7

# %%
by_station = by_station.reset_index()

station = by_station[ 
    (by_station["station"] == "CONEY IS-STILLW")
    ].groupby(["datetime"])['daily_entries'].agg(['max'])

plt.figure(figsize=(10,4))
plt.plot(station);

# %%
# unique_stations = by_station.station.unique()

# %%
# plt.figure(figsize=(10,4))

# for i in unique_stations:
#     station= by_station[by_station['station'] == i
#     ].groupby(["datetime"])['daily_entries'].agg(['max'])
#     plt.plot(station[:-1]);

# %% [markdown]
# ### challenge 8

# %% [markdown]
# ## entries by turnstile and time

# %%
# by_turnstile_time = mta.groupby(['c_a', 'unit', 'scp', 'station', mta.datetime.dt.hour])

# %%
# mta_hourly = by_turnstile_time['entries'].min().reset_index()
# mta_hourly

# %%
# mta_hourly['hourly_entries'] = mta_hourly.groupby(['c_a', 'unit', 'scp', 'station'])['entries'].diff().shift(-1)

# %%
by_turnstile_time = mta.groupby(['c_a', 'unit', 'scp', 'station', 'datetime'])
mta_hourly = by_turnstile_time['entries'].min().reset_index()

# %%
mta_hourly['hourly_entries'] = mta_hourly.groupby(['station', mta_hourly.datetime])['entries'].diff().shift(-1)

# %%
mta_hourly.describe([.95,.97])

# %%
mta_hourly = mta_hourly.reset_index()
test = mta_hourly[mta_hourly.hourly_entries.notnull()]

plt.clf()
plt.figure(figsize=(10,4))
sns.distplot(test.hourly_entries)

# %%
#dropping rows with negative hourly entries
mta_hourly = mta_hourly[mta_hourly.hourly_entries >= 0]

# %%
#dropping rows with the top .3% of daily entries
mta_hourly = mta_hourly[mta_hourly.hourly_entries < mta_hourly.hourly_entries.quantile(q =.997)]

# %%
check_distribution = mta_hourly[mta_hourly.hourly_entries.notnull()]

plt.figure(figsize=(10,4))
sns.distplot(check_distribution.hourly_entries)

# %%
mta_hourly.to_csv(r'mta_hourly.csv')

# %%
# mta_hourly = pd.read_csv('mta_hourly.csv')

# %%
mta_hourly.head()
# Out:
#    Unnamed: 0  index   c_a  unit       scp station  datetime  entries  \
# 0           1      1  A002  R051  02-00-00   59 ST         3  6962094
# 1           3      3  A002  R051  02-00-00   59 ST         7  6962111
# 2           4      4  A002  R051  02-00-00   59 ST         8  6972704
# 3           5      5  A002  R051  02-00-00   59 ST         9  6997615
# 4           7      7  A002  R051  02-00-00   59 ST        11  6962243
#
#    hourly_entries
# 0         10599.0
# 1         10593.0
# 2         24911.0
# 3         45372.0
# 4         10514.0

# %%
#sum entries for each hour and sort them
