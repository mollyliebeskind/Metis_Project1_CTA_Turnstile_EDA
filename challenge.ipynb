# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'svg'
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# # Download and load MTA turnstile data

# %%
def all_saturdays(start_date, end_date):
    saturday_list = pd.date_range(start =start_date, end =end_date,
                              freq='W-SAT').strftime('%m/%d/%Y').tolist()
    return saturday_list

# %%
def import_mta(date):
    formatted_date = date[-2:]+date[:2]+date[3:5]
    base_url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    date_url = base_url.format(formatted_date)
    date_data = pd.read_csv(date_url)
    return date_data

# %%
def mta_to_df(saturday_list):
    dict_of_dfs = {}
    for saturday in saturday_list:
        dict_of_dfs[saturday] = pd.DataFrame(import_mta(saturday))
    mta =pd.DataFrame()
    for val in dict_of_dfs.values():
        mta = pd.concat([mta, val])
    return mta

# %%
saturday_list = all_saturdays('5/1/2019','5/31/2019')

# %%
# print(saturday_list)

# %%
mta = mta_to_df(saturday_list)

# %%
mta

# %% [markdown]
# # In case of later breakage

# %%
mta.to_csv(r'mta.csv')

# %%
# mta = pd.read_csv('mta.csv')

# %% [markdown]
# # Cleaning

# %%
mta.info()

# %%
mta.columns = mta.columns.str.strip().str.lower()

# %%
mta.columns

# %%
mta['datetime'] = mta[['date', 'time']].apply(lambda x: ''.join(x), axis=1)

# %%
mta.datetime = pd.to_datetime(mta.datetime,format="%m/%d/%Y%H:%M:%S")

# %%
mta.datetime

# %% [markdown]
# ### Group the data so that it represents daily entries for each turnstile (hint: pd.groupby or DataFrame.groupby)

# %% [markdown]
# # Ignore this mess

# %%
mta.groupby(['unit', 'scp'])[['entries']].sum()

# %%
mta.groupby[['unit', 'station']]

# %%
# mta_datetime = mta[['c/a','unit','scp', 'datetime']]
# mta_datetime

# %%
# mta_temp = pd.merge(mta_datetime, mta, on=['c/a','unit','scp'])
# mta_temp

# %%
# mta_filtered = mta_temp[mta_temp['datetime_x'] > mta_temp['datetime_y']]
# mta_filtered
