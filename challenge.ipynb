# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %% [markdown]
# # Download and load MTA turnstile data

# %%
def all_saturdays(start_date, end_date):
    modified_end_date = datetime.datetime.strptime(end_date,'%m/%d/%Y')+ datetime.timedelta(weeks = 1)
    saturday_list = pd.date_range(start =start_date, end =modified_end_date,
                              freq='W-SAT').strftime('%m/%d/%Y').tolist()
    return saturday_list

# %%
def import_mta(date):
    formatted_date = date[-2:]+date[:2]+date[3:5]
    base_url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    date_url = base_url.format(formatted_date)
    date_data = pd.read_csv(date_url)
    return date_data

# %%
def mta_to_df(saturday_list):
    dict_of_dfs = {}
    for saturday in saturday_list:
        dict_of_dfs[saturday] = pd.DataFrame(import_mta(saturday))
    mta =pd.DataFrame()
    for val in dict_of_dfs.values():
        mta = pd.concat([mta, val])
    return mta

# %%
start_date = input("Enter start date (X/X/XXXX): ")
end_date = input("Enter end date: ")
# Out:
# Enter start date (X/X/XXXX): 5/1/2019
# Enter end date: 5/31/2019

# %%
saturday_list = all_saturdays(start_date,end_date)

# %%
# print(saturday_list)

# %%
mta = mta_to_df(saturday_list)

# %%
mta.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7035249
# 1  REGULAR  7035269
# 2  REGULAR  7035292
# 3  REGULAR  7035392
# 4  REGULAR  7035651
#
#    EXITS
# 0                                            2384833
# 1                                            2384840
# 2                                            2384875
# 3                                            2384951
# 4                                            2385020

# %% [markdown]
# # In case of later breakage

# %%
mta.to_csv(r'mta.csv')

# %%
# mta = pd.read_csv('mta.csv')

# %% [markdown]
# # Cleaning

# %%
mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1026784 entries, 0 to 1026783
# Data columns (total 12 columns):
# Unnamed: 0                                                              1026784 non-null int64
# C/A                                                                     1026784 non-null object
# UNIT                                                                    1026784 non-null object
# SCP                                                                     1026784 non-null object
# STATION                                                                 1026784 non-null object
# LINENAME                                                                1026784 non-null object
# DIVISION                                                                1026784 non-null object
# DATE                                                                    1026784 non-null object
# TIME                                                                    1026784 non-null object
# DESC                                                                    1026784 non-null object
# ENTRIES                                                                 1026784 non-null int64
# EXITS                                                                   1026784 non-null int64
# dtypes: int64(3), object(9)
# memory usage: 94.0+ MB

# %%
mta.columns
# Out:
# Index(['Unnamed: 0', 'C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION',
#        'DATE', 'TIME', 'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
mta.columns = mta.columns.str.strip().str.lower().str.replace('/',"_")

# %%
mta.columns
# Out:
# Index(['unnamed: 0', 'c_a', 'unit', 'scp', 'station', 'linename', 'division',
#        'date', 'time', 'desc', 'entries', 'exits'],
#       dtype='object')

# %%
mta["datetime"] = pd.to_datetime(mta.date + " " + mta.time, format="%m/%d/%Y %H:%M:%S")

# %%
mta.head()
# Out:
#    unnamed: 0   c_a  unit       scp station linename division        date  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019
#
#        time     desc  entries    exits            datetime
# 0  00:00:00  REGULAR  7035249  2384833 2019-04-27 00:00:00
# 1  04:00:00  REGULAR  7035269  2384840 2019-04-27 04:00:00
# 2  08:00:00  REGULAR  7035292  2384875 2019-04-27 08:00:00
# 3  12:00:00  REGULAR  7035392  2384951 2019-04-27 12:00:00
# 4  16:00:00  REGULAR  7035651  2385020 2019-04-27 16:00:00

# %%
mta.date.value_counts().sort_index()
# Out:
# 04/27/2019    28914
# 04/28/2019    28982
# 04/29/2019    30972
# 04/30/2019    28982
# 05/01/2019    29624
# 05/02/2019    29871
# 05/03/2019    29512
# 05/04/2019    28963
# 05/05/2019    28954
# 05/06/2019    29008
# 05/07/2019    30355
# 05/08/2019    29280
# 05/09/2019    28793
# 05/10/2019    28735
# 05/11/2019    28807
# 05/12/2019    28922
# 05/13/2019    29877
# 05/14/2019    30074
# 05/15/2019    30589
# 05/16/2019    29940
# 05/17/2019    30472
# 05/18/2019    29052
# 05/19/2019    29225
# 05/20/2019    29501
# 05/21/2019    30146
# 05/22/2019    27745
# 05/23/2019    28021
# 05/24/2019    29673
# 05/25/2019    28855
# 05/26/2019    29063
# 05/27/2019    29068
# 05/28/2019    28873
# 05/29/2019    29095
# 05/30/2019    29190
# 05/31/2019    29651
# Name: date, dtype: int64

# %%
mta.date = pd.to_datetime(mta.date,format="%m/%d/%Y")

# %%
mta = mta[(mta.date >= start_date)]

# %%
mta = mta[(mta.date <= end_date)]

# %%
mta.drop(columns = ['time'], inplace = True)

# %%
mta
# Out:
#          unnamed: 0    c_a  unit       scp        station linename division  \
# 0                 0   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1                 1   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2                 2   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3                 3   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4                 4   A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...             ...    ...   ...       ...            ...      ...      ...
# 1026779      203790  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1026780      203791  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1026781      203792  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1026782      203793  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1026783      203794  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#               date     desc  entries    exits            datetime
# 0       2019-04-27  REGULAR  7035249  2384833 2019-04-27 00:00:00
# 1       2019-04-27  REGULAR  7035269  2384840 2019-04-27 04:00:00
# 2       2019-04-27  REGULAR  7035292  2384875 2019-04-27 08:00:00
# 3       2019-04-27  REGULAR  7035392  2384951 2019-04-27 12:00:00
# 4       2019-04-27  REGULAR  7035651  2385020 2019-04-27 16:00:00
# ...            ...      ...      ...      ...                 ...
# 1026779 2019-05-31  REGULAR     5554      378 2019-05-31 09:00:00
# 1026780 2019-05-31  REGULAR     5554      378 2019-05-31 12:10:52
# 1026781 2019-05-31  REGULAR     5554      378 2019-05-31 13:00:00
# 1026782 2019-05-31  REGULAR     5554      378 2019-05-31 17:00:00
# 1026783 2019-05-31  REGULAR     5554      378 2019-05-31 21:00:00
#
# [1026784 rows x 12 columns]

# %% [markdown]
# ### Group the data so that it represents daily entries for each turnstile (hint: pd.groupby or DataFrame.groupby)

# %%
mta.head(10)
# Out:
#    unnamed: 0   c_a  unit       scp station linename division       date  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-27
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-27
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-27
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-27
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-27
# 5           5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-27
# 6           6  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-28
# 7           7  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-28
# 8           8  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-28
# 9           9  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-04-28
#
#       desc  entries    exits            datetime
# 0  REGULAR  7035249  2384833 2019-04-27 00:00:00
# 1  REGULAR  7035269  2384840 2019-04-27 04:00:00
# 2  REGULAR  7035292  2384875 2019-04-27 08:00:00
# 3  REGULAR  7035392  2384951 2019-04-27 12:00:00
# 4  REGULAR  7035651  2385020 2019-04-27 16:00:00
# 5  REGULAR  7035930  2385070 2019-04-27 20:00:00
# 6  REGULAR  7036100  2385087 2019-04-28 00:00:00
# 7  REGULAR  7036119  2385088 2019-04-28 04:00:00
# 8  REGULAR  7036125  2385103 2019-04-28 08:00:00
# 9  REGULAR  7036197  2385155 2019-04-28 12:00:00

# %%
by_turnstile_date = mta.groupby(['c_a', 'unit', 'scp', 'station', 'date'])

# %%
mta_daily = by_turnstile_date['entries'].min().reset_index()

# %%
mta_daily.head()
# Out:
#     c_a  unit       scp station       date  entries
# 0  A002  R051  02-00-00   59 ST 2019-04-27  7035249
# 1  A002  R051  02-00-00   59 ST 2019-04-28  7036100
# 2  A002  R051  02-00-00   59 ST 2019-04-29  7036746
# 3  A002  R051  02-00-00   59 ST 2019-04-30  7038242
# 4  A002  R051  02-00-00   59 ST 2019-05-01  7039729

# %%
mta_daily['daily_entries'] = mta_daily.groupby(['c_a', 'unit', 'scp', 'station'])['entries'].diff().shift(-1)

# %%
mta_daily.head(50)
# Out:
#      c_a  unit       scp station       date  entries  daily_entries
# 0   A002  R051  02-00-00   59 ST 2019-04-27  7035249          851.0
# 1   A002  R051  02-00-00   59 ST 2019-04-28  7036100          646.0
# 2   A002  R051  02-00-00   59 ST 2019-04-29  7036746         1496.0
# 3   A002  R051  02-00-00   59 ST 2019-04-30  7038242         1487.0
# 4   A002  R051  02-00-00   59 ST 2019-05-01  7039729         1574.0
# 5   A002  R051  02-00-00   59 ST 2019-05-02  7041303         1577.0
# 6   A002  R051  02-00-00   59 ST 2019-05-03  7042880         1588.0
# 7   A002  R051  02-00-00   59 ST 2019-05-04  7044468          746.0
# 8   A002  R051  02-00-00   59 ST 2019-05-05  7045214          535.0
# 9   A002  R051  02-00-00   59 ST 2019-05-06  7045749         1566.0
# 10  A002  R051  02-00-00   59 ST 2019-05-07  7047315         1459.0
# 11  A002  R051  02-00-00   59 ST 2019-05-08  7048774         1568.0
# 12  A002  R051  02-00-00   59 ST 2019-05-09  7050342         1584.0
# 13  A002  R051  02-00-00   59 ST 2019-05-10  7051926         1557.0
# 14  A002  R051  02-00-00   59 ST 2019-05-11  7053483          808.0
# 15  A002  R051  02-00-00   59 ST 2019-05-12  7054291          457.0
# 16  A002  R051  02-00-00   59 ST 2019-05-13  7054748         1390.0
# 17  A002  R051  02-00-00   59 ST 2019-05-14  7056138         1519.0
# 18  A002  R051  02-00-00   59 ST 2019-05-15  7057657         1597.0
# 19  A002  R051  02-00-00   59 ST 2019-05-16  7059254         1703.0
# 20  A002  R051  02-00-00   59 ST 2019-05-17  7060957         1524.0
# 21  A002  R051  02-00-00   59 ST 2019-05-18  7062481          799.0
# 22  A002  R051  02-00-00   59 ST 2019-05-19  7063280          703.0
# 23  A002  R051  02-00-00   59 ST 2019-05-20  7063983         1510.0
# 24  A002  R051  02-00-00   59 ST 2019-05-21  7065493         1608.0
# 25  A002  R051  02-00-00   59 ST 2019-05-22  7067101         1668.0
# 26  A002  R051  02-00-00   59 ST 2019-05-23  7068769         1520.0
# 27  A002  R051  02-00-00   59 ST 2019-05-24  7070289         1541.0
# 28  A002  R051  02-00-00   59 ST 2019-05-25  7071830          809.0
# 29  A002  R051  02-00-00   59 ST 2019-05-26  7072639          594.0
# 30  A002  R051  02-00-00   59 ST 2019-05-27  7073233          734.0
# 31  A002  R051  02-00-00   59 ST 2019-05-28  7073967         1493.0
# 32  A002  R051  02-00-00   59 ST 2019-05-29  7075460         1525.0
# 33  A002  R051  02-00-00   59 ST 2019-05-30  7076985         1485.0
# 34  A002  R051  02-00-00   59 ST 2019-05-31  7078470            NaN
# 35  A002  R051  02-00-01   59 ST 2019-04-27  6268264          734.0
# 36  A002  R051  02-00-01   59 ST 2019-04-28  6268998          498.0
# 37  A002  R051  02-00-01   59 ST 2019-04-29  6269496         1220.0
# 38  A002  R051  02-00-01   59 ST 2019-04-30  6270716         1237.0
# 39  A002  R051  02-00-01   59 ST 2019-05-01  6271953         1278.0
# 40  A002  R051  02-00-01   59 ST 2019-05-02  6273231         1263.0
# 41  A002  R051  02-00-01   59 ST 2019-05-03  6274494         1244.0
# 42  A002  R051  02-00-01   59 ST 2019-05-04  6275738          632.0
# 43  A002  R051  02-00-01   59 ST 2019-05-05  6276370          482.0
# 44  A002  R051  02-00-01   59 ST 2019-05-06  6276852         1245.0
# 45  A002  R051  02-00-01   59 ST 2019-05-07  6278097         1222.0
# 46  A002  R051  02-00-01   59 ST 2019-05-08  6279319         1328.0
# 47  A002  R051  02-00-01   59 ST 2019-05-09  6280647         1225.0
# 48  A002  R051  02-00-01   59 ST 2019-05-10  6281872         1296.0
# 49  A002  R051  02-00-01   59 ST 2019-05-11  6283168          680.0
